# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
df = pd.read_csv('spectrum-timing.csv', index_col=0)
df_no_symm = pd.read_csv('spectrum-timing-no-symm.csv', index_col=0)
df_no_symm.head()
# Out:
#     L    gs_time  sf_time
# 0   8   0.028580      0.0
# 1  12   0.003236      0.0
# 2  16   0.041609      0.0
# 3  20   1.010785      0.0
# 4  24  26.321470      0.0

# %%
sns.scatterplot(data=df, x='L', y='gs_time')
sns.scatterplot(data=df_no_symm, x='L', y='gs_time')
plt.xlabel('System size')
plt.ylabel('Time (s)')
plt.legend(['Symmetries', 'No Symmetries'])
plt.title('Ground state search time')
# Out:
# Text(0.5, 1.0, 'Ground state search time')

# %%
sns.scatterplot(data=df, x='L', y='sf_time')
plt.xlabel('System size')
plt.ylabel('Time (s)')
plt.title('Spectral function computation time ($\langle S^z(t) S^z(0) \\rangle_0$)')
# Out:
# Text(0.5, 1.0, 'Spectral function computation time ($\\langle S^z(t) S^z(0) \\rangle_0$)')
